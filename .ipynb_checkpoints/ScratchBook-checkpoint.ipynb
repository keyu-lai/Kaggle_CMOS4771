# %%
# %matplotlib inline

import random
import classifier
reload(classifier)

import pandas as pd
import numpy
from IPython.display import display
from sklearn.feature_extraction import DictVectorizer
from sklearn.cross_validation import train_test_split
from classifier import encode_onehot, encode_label
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures

def prepare_data(df):
    df3 = df
    df1 = pd.DataFrame(df.loc[:,[u'27',u'28',u'29',u'30',
                                 u'31',u'32',u'33',u'34',
                                 u'35',u'36',u'37',u'38',
                                 u'39',u'40',u'41',u'42',
                                 u'43',u'44',u'45',u'46',
                                 u'47',u'48',u'49',u'50',
                                 u'51',u'52',u'53',u'54',
                                 u'55']])
    #0 , 26 8, 5 , 14, 23 , 58 -> boss
    #17, 56, 16,9,, 25, 57 -> yes
    #20, 18, 7 -> no
    #df2 = pd.DataFrame(df.loc[:,[u'18',u'20',u'23',u'25',u'26']])
    df2 = pd.DataFrame(df.drop([u'27',u'28',u'29',u'30',
                                 u'31',u'32',u'33',u'34',
                                 u'35',u'36',u'37',u'38',
                                 u'39',u'40',u'41',u'42',
                                 u'43',u'44',u'45',u'46',
                                 u'47',u'48',u'49',u'50',
                                 u'51',u'52',u'53',u'54',
                                 u'55'],axis=1))
    
    return df1, df2, df3

def encode(dataset):
    drop_cols = []
    for i in dataset.columns:
        if isinstance(dataset[i].values[0], basestring):
            drop_cols = drop_cols + [i]
    
    return encode_label(dataset, drop_cols)

def encode_with_test(train, test):
    agg_data = pd.concat([train, test],axis=0,ignore_index=True)
    agg_data= encode(agg_data)
    
    return agg_data._slice(slice(0,train.shape[0]),axis=0), agg_data._slice(slice(train.shape[0],agg_data.shape[0]),axis=0)

train = pd.read_csv('data.csv')
label = train['label']
train = train.drop('label',1)
print len(train.columns)
X_quiz = pd.read_csv('quiz.csv')

#split the dataset
X_train, X_test, y_train, y_test = train_test_split(train, label)
train_1, train_2, train_all = prepare_data(X_train)
test_1, test_2, test_all = prepare_data(X_test)
quiz_1, quiz_2, quiz_all = prepare_data(X_quiz)
                             
#agg_data = pd.concat([train, X_quiz],axis=0,ignore_index=True)


#display(agg_data.shape[0])
#train = agg_data._slice(slice(0,train.shape[0]),0)
#X_quiz = agg_data._slice(slice(train.shape[0],agg_data.shape[0]),0)
#pca = PCA(n_components=100)
#train = pca.fit(train).transform(train)
#display(train.shape)
#display(X_quiz.shape)
# Out:
# 52

# %%
import classifier
reload(classifier)

import contest
reload(contest)

from contest import score

score()
# Out:
# Creating bleding train set and valid set...
# 0 RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=398, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2

# %%
import classifier
reload(classifier)

import contest
reload(contest)

from contest import run_local, score

score()
# Out:
# Creating bleding train set and valid set...
# 0 RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=398, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 1 RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=812, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 2 ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#            oob_score=False, random_state=312, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 3 ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#            max_depth=None, max_features=None, max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#            oob_score=False, random_state=4018, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 4 XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.2, max_delta_step=0, max_depth=7,
#        min_child_weight=1, missing=None, n_estimators=800, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 5 AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=1,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=417, verbose=0, warm_start=False),
#           learning_rate=0.5, n_estimators=50, random_state=None)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 6 AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=None, max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=1,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#            oob_score=False, random_state=2345, verbose=0, warm_start=False),
#           learning_rate=0.3, n_estimators=50, random_state=None)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 7 BaggingClassifier(base_estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=1,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=123, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=1245, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 8 BaggingClassifier(base_estimator=ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_samples_leaf=1, min_samples_split=1,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=50, n_jobs=1, oob_score=False,
#          random_state=456, verbose=0, warm_start=False)
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 9 BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=200, n_jobs=-1, oob_score=False,
#          random_state=1556, verbose=0, warm_start=False)
# Fold 0
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# Fold 1
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# Fold 2
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# Fold 3
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# Fold 4
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# 10 DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 11 DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 12 KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 13 KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=2, p=2,
#            weights='uniform')
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# 14 KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')
# Fold 0
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Blending models by logistic regression...
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# /home/ubuntu/miniconda2/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:1207: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    0.5s finished
# Best score: 0.855
# Best parameters set:
# 	clf__C: 0.7
# 	clf__solver: 'newton-cg'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8114347d8a06> in <module>()
#       7 from contest import run_local, score
#       8
# ----> 9 score()
#
# /home/ubuntu/extern/Kaggle_CMOS4771/contest.pyc in score()
#     108
#     109     predictions, sco = blend_clf(clfs, X_train.as_matrix(),X_test.as_matrix(),y_train.as_matrix())
# --> 110     filename = "stack9." + sc + '.' + time.strftime("%H%M%S") + '.txt'
#     111     print('Writing to ' + filename)
#     112     write_out(predictions,filename)
#
# NameError: global name 'sc' is not defined

# %%
import classifier
reload(classifier)

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from classifier import train_rf, train_gbc, train_ada_boost


print train_1.shape
train_1 = encode(X_train)
X_train1, X_test1, y_train1, y_test1 = train_test_split(train_1, y_train, test_size=0.1)

sgd = SGDClassifier(loss="perceptron", penalty="l2",shuffle=True,alpha=0.00001,epsilon=0.01, verbose=100, random_state = 123)
gbc = GradientBoostingClassifier(loss='deviance',random_state=0,n_estimators=200,learning_rate=0.05,max_depth=7)
svm = SVC(kernel='linear', C=0.3)
rf = RandomForestClassifier(n_estimators=200, max_depth=None, min_samples_split=1, random_state=123, max_features='sqrt')
xtree = ExtraTreesClassifier(n_jobs=-1,n_estimators=500,max_depth=None, max_features=None,random_state=0)
adaBoost = AdaBoostClassifier(n_estimators=600, learning_rate=1.5)
gnb = BernoulliNB()
dt = DecisionTreeClassifier(criterion='entropy',splitter='best')
nn = KNeighborsClassifier(n_neighbors=3)

clf = adaBoost.fit(X_train1,y_train1)
predictions = clf.predict(X_test1)
print classification_report(y_test1, predictions, digits=4)
# Out:
# (95127, 52)
#              precision    recall  f1-score   support
#
#          -1     0.8968    0.9002    0.8985      5321
#           1     0.8727    0.8686    0.8706      4192
#
# avg / total     0.8862    0.8863    0.8862      9513

# %%
sgd = SGDClassifier(loss="hinge", penalty="l2",shuffle=True,alpha=0.0001,epsilon=0.1, verbose=1)


sgd = sgd.fit(X_train1, y_train1)
predictions = sgd.predict(X_test1)
print classification_report(y_test1, predictions, digits=4)
# Out:
# -- Epoch 1
# Norm: 9865056.23, NNZs: 1365, Bias: -2291.872243, T: 85614, Avg. loss: 1205128548907.065186
# Total training time: 0.21 seconds.
# -- Epoch 2
# Norm: 6156770.31, NNZs: 1369, Bias: -2371.374051, T: 171228, Avg. loss: 690710374368.672729
# Total training time: 0.41 seconds.
# -- Epoch 3
# Norm: 4991685.11, NNZs: 1370, Bias: -2411.293603, T: 256842, Avg. loss: 494743951102.034363
# Total training time: 0.62 seconds.
# -- Epoch 4
# Norm: 4264099.25, NNZs: 1372, Bias: -2435.149700, T: 342456, Avg. loss: 389167957628.018005
# Total training time: 0.82 seconds.
# -- Epoch 5
# Norm: 3891670.13, NNZs: 1372, Bias: -2458.047829, T: 428070, Avg. loss: 322411872423.343201
# Total training time: 1.03 seconds.
#              precision    recall  f1-score   support
#
#          -1     0.6991    0.9178    0.7936      5280
#           1     0.8318    0.5072    0.6302      4233
#
# avg / total     0.7582    0.7351    0.7209      9513

# %%
import classifier
reload(classifier)

from classifier import train_SGD_SVM
from sklearn.metrics import classification_report

svm_clf = train_SGD_SVM(X_train3, y_train3)
predictions = svm_clf.predict(X_test3)
print classification_report(y_test3, predictions)
# Out:
# ['clf__average', 'clf__l1_ratio', 'clf__penalty', 'clf__warm_start', 'clf__random_state', 'clf', 'clf__n_iter', 'clf__learning_rate', 'clf__verbose', 'steps', 'clf__loss', 'clf__class_weight', 'clf__fit_intercept', 'clf__power_t', 'clf__n_jobs', 'clf__eta0', 'clf__alpha', 'clf__shuffle', 'clf__epsilon']
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# -- Epoch 1
# Norm: 23.02, NNZs: 33, Bias: 0.304084, T: 499, Avg. loss: 533.381897
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 11.81, NNZs: 33, Bias: -3.719816, T: 998, Avg. loss: 377.859071
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 12.63, NNZs: 33, Bias: -2.187557, T: 1497, Avg. loss: 299.342091
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 7.12, NNZs: 33, Bias: -0.819241, T: 1996, Avg. loss: 250.458674
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 12.35, NNZs: 33, Bias: -0.846817, T: 2495, Avg. loss: 216.775159
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 26.88, NNZs: 33, Bias: 0.846839, T: 500, Avg. loss: 540.865625
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 10.97, NNZs: 33, Bias: 0.740469, T: 1000, Avg. loss: 387.385494
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 24.69, NNZs: 33, Bias: 2.792540, T: 1500, Avg. loss: 308.386019
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 16.97, NNZs: 33, Bias: 1.808922, T: 2000, Avg. loss: 259.346941
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 11.98, NNZs: 33, Bias: 1.339112, T: 2500, Avg. loss: 225.161174
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 22.89, NNZs: 31, Bias: -0.070369, T: 501, Avg. loss: 487.782520
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 7.67, NNZs: 31, Bias: 1.508519, T: 1002, Avg. loss: 351.323875
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 9.46, NNZs: 31, Bias: 1.318522, T: 1503, Avg. loss: 278.816314
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 11.39, NNZs: 31, Bias: 0.860544, T: 2004, Avg. loss: 233.921081
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 6.35, NNZs: 31, Bias: 0.436168, T: 2505, Avg. loss: 202.772871
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 2.90, NNZs: 33, Bias: -0.028250, T: 499, Avg. loss: 116.536964
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 3.35, NNZs: 33, Bias: -0.092701, T: 998, Avg. loss: 71.175266
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 2.34, NNZs: 33, Bias: -0.134980, T: 1497, Avg. loss: 52.676746
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1.10, NNZs: 33, Bias: -0.070841, T: 1996, Avg. loss: 42.327824
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.95, NNZs: 33, Bias: -0.038038, T: 2495, Avg. loss: 35.607442
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 2.63, NNZs: 33, Bias: -0.138793, T: 500, Avg. loss: 110.893957
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 2.08, NNZs: 33, Bias: -0.212900, T: 1000, Avg. loss: 69.600368
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 1.32, NNZs: 33, Bias: -0.097611, T: 1500, Avg. loss: 51.962776
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1.26, NNZs: 33, Bias: -0.230210, T: 2000, Avg. loss: 41.971905
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.76, NNZs: 33, Bias: -0.152252, T: 2500, Avg. loss: 35.453884
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 2.06, NNZs: 31, Bias: 0.476496, T: 501, Avg. loss: 116.636635
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 2.19, NNZs: 31, Bias: 0.587823, T: 1002, Avg. loss: 70.546391
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 1.52, NNZs: 31, Bias: 0.448479, T: 1503, Avg. loss: 52.045175
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 1.13, NNZs: 31, Bias: 0.487663, T: 2004, Avg. loss: 41.722391
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.42, NNZs: 31, Bias: 0.492790, T: 2505, Avg. loss: 35.032694
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 16.44, NNZs: 32, Bias: 5.011831, T: 750, Avg. loss: 451.652656
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 11.59, NNZs: 32, Bias: 2.301155, T: 1500, Avg. loss: 304.544004
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 12.25, NNZs: 33, Bias: 3.000351, T: 2250, Avg. loss: 235.613425
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 4.37, NNZs: 33, Bias: 1.871957, T: 3000, Avg. loss: 194.494798
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 11.81, NNZs: 33, Bias: 1.856283, T: 3750, Avg. loss: 166.831512
# Total training time: 0.00 seconds.
# Best score: 0.403
# Best parameters set:
# 	clf__alpha: 0.001
#              precision    recall  f1-score   support
#
#          -1       0.25      0.01      0.01       143
#           1       0.42      0.97      0.59       107
#
# avg / total       0.32      0.42      0.26       250
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s finished

# %%
import classifier
reload(classifier)

from classifier import train_ada_boost
from sklearn.metrics import classification_report

dt_clf = train_ada_boost(X_train3,y_train3)
predictions = dt_clf.predict(X_test3)
print classification_report(y_test3, predictions)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.6s finished
# Best score: 0.681
# Best parameters set:
# 	clf__n_estimators: 100
#              precision    recall  f1-score   support
#
#          -1       0.69      0.80      0.74       133
#           1       0.72      0.60      0.65       117
#
# avg / total       0.71      0.70      0.70       250

# %%
import classifier
reload(classifier)

from sklearn.ensemble import ExtraTreesClassifier
from classifier import train_xtree_classifer, train_rf, train_SGD_SVM, train_friedman_xgbm
from sklearn.metrics import classification_report

# XTree is okay in set 3

train_3 = encode(X_train)
X_train3, X_test3, y_train3, y_test3 = train_test_split(train_3, y_train)

xtree = ExtraTreesClassifier(n_jobs=-1,n_estimators=200,max_depth=None, max_features='sqrt',random_state=0)
xtree.fit(X_train3, y_train3)
predictions = xtree.predict(X_test3)
print classification_report(y_test3, predictions, digits=4)
# Out:
#              precision    recall  f1-score   support
#
#          -1     0.9254    0.9680    0.9462     13349
#           1     0.9565    0.9001    0.9275     10433
#
# avg / total     0.9390    0.9382    0.9380     23782
